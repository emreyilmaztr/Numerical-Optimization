# %%
import numpy as np
import matplotlib.pyplot as plt
m = 3
b = -2
n = 100
mu, sigma = 0, 0.5 # mean and standard deviation
noise = np.random.normal(mu, sigma, n)

x = np.arange(-5, 5, 0.1)

y = 3 * x - 2

plt.plot(x, y, 'g', x, noise + y, 'r:')
